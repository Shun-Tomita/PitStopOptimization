# %% [markdown]
# ### [DABP Final Project]
# ### The Expansion of the Pit Stop Program in San Francisco

# %% [markdown]
# # Generating Grids on the Map

# %% [markdown]
# This Jupyter notebook includes codes for generating grids on the map. This code is used to visualize our model outcomes on the map with color scales.

# %% [markdown]
# * we borrowed code from https://www.jpytr.com/post/analysinggeographicdatawithfolium/ and modified it to our need.

# %%
# import relevant libraries
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import folium
from folium.plugins import MarkerCluster

# %%
def get_geojson_grid(upper_right, lower_left, nlat=6, nlong=5):
    """Returns a grid of geojson rectangles, and computes the exposure in each section of the grid based on the vessel data.

    Parameters
    ----------
    upper_right: array_like
        The upper right hand corner of "grid of grids" (the default is the upper right hand [lat, lon] of the USA).

    lower_left: array_like
        The lower left hand corner of "grid of grids"  (the default is the lower left hand [lat, lon] of the USA).

    n: integer
        The number of rows/columns in the (n,n) grid.

    Returns
    -------

    list
        List of "geojson style" dictionary objects   
    """

    all_boxes = []

    lat_steps = np.linspace(lower_left[0], upper_right[0], nlat+1)
    lon_steps = np.linspace(lower_left[1], upper_right[1], nlong+1)

    lat_stride = lat_steps[1] - lat_steps[0]
    lon_stride = lon_steps[1] - lon_steps[0]

    for lat in lat_steps[:-1]:
        for lon in lon_steps[:-1]:
            # Define dimensions of box in grid
            upper_left = [lon, lat + lat_stride]
            upper_right = [lon + lon_stride, lat + lat_stride]
            lower_right = [lon + lon_stride, lat]
            lower_left = [lon, lat]

            # Define json coordinates for polygon
            coordinates = [
                upper_left,
                upper_right,
                lower_right,
                lower_left,
                upper_left
            ]

            geo_json = {"type": "FeatureCollection",
                        "properties":{
                            "lower_left": lower_left,
                            "upper_right": upper_right
                        },
                        "features":[]}

            grid_feature = {
                "type":"Feature",
                "geometry":{
                    "type":"Polygon",
                    "coordinates": [coordinates],
                }
            }

            geo_json["features"].append(grid_feature)

            all_boxes.append(geo_json)

    return all_boxes

# %%
# set coordinate boundaries of SF
lower_left = [37.708448, -122.514731]
upper_right = [37.811151, -122.357476]

# %%
# get coordinates of center of SF
sf_lat = np.mean([37.708448, 37.811151])
sf_long = np.mean([-122.514731, -122.357476])

# %%
# generate empty grid
m = folium.Map([sf_lat, sf_long], zoom_start = 12.2, tiles='cartodbpositron')
grid = get_geojson_grid(upper_right, lower_left , nlat=20, nlong=30)

for i, geo_json in enumerate(grid):

    color = 'White'

    gj = folium.GeoJson(geo_json,
                        style_function=lambda feature, color=color: {
                                                                        'fillColor': color,
                                                                        'color':"black",
                                                                        'weight': 0.7,
                                                                        'dashArray': '1, 1',
                                                                        'fillOpacity': 0.1,
                                                                    })

    m.add_child(gj)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40562593320ba7a52907379a179e2bb2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40562593320ba7a52907379a179e2bb2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40562593320ba7a52907379a179e2bb2 = L.map(
#                 &quot;map_40562593320ba7a52907379a179e2bb2&quot;,
#                 {
#                     center: [37.7597995, -122.4361035],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12.2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e323de26e201318ed0fee3976126f450 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_40562593320ba7a52907379a179e2bb2);
#
#
#         function geo_json_2dcf160dd09d50b94a25f3719f630b5b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;1, 1&quot;, &quot;fillColor&quot;: &quot;White&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_2dcf160dd09d50b94a25f3719f630b5b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2dcf160dd09d50b94a25f3719f630b5b = L.geoJson(null, {
#                 onEachFeature: geo_json_2dcf160dd09d50b94a25f3719f630b5b_onEachFeature,
#
#                 style: geo_json_2dcf160dd09d50b94a25f3719f630b5b_styler,
#         });
#
#         function geo_json_2dcf160dd09d50b94a25f3719f630b5b_add (data) {
#             geo_json_2dcf160dd09d50b94a25f3719f630b5b
#                 .addData(data)
#                 .addTo(map_40562593320ba7a52907379a179e2bb2);
#         }
#             geo_json_2dcf160dd09d50b94a25f3719f630b5b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.514731, 37.71358315], [-122.50948916666667, 37.71358315], [-122.50948916666667, 37.708448], [-122.514731, 37.708448], [-122.514731, 37.71358315]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;properties&quot;: {&quot;lower_left&quot;: [-122.514731, 37.708448], &quot;upper_right&quot;: [-122.50948916666667, 37.71358315]}, &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_727ac7fb197a4a866bbf0ef3c98cb003_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;1, 1&quot;, &quot;fillColor&quot;: &quot;White&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_727ac7fb197a4a866bbf0ef3c98cb003_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_727ac7fb197a4a866bbf0ef3c98cb003 = L.geoJson(null, {
#                 onEachFeature: geo_json_727ac7fb197a4a866bbf0ef3c98cb003_onEachFeature,
#
#                 style: geo_json_727ac7fb197a4a866bbf0ef3c98cb003_styler,
#         });
#
#         function geo_json_727ac7fb197a4a866bbf0ef3c98cb003_add (data) {
#             geo_json_727ac7fb197a4a866bbf0ef3c98cb003
#                 .addData(data)
#                 .addTo(map_40562593320ba7a52907379a179e2bb2);
#         }
#             geo_json_727ac7fb197a4a866bbf0ef3c98cb003_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.50948916666667, 37.71358315], [-122.50424733333334, 37.71358315], [-122.50424733333334, 37.708448], [-122.50948916666667, 37.708448], [-122.50948916666667, 37.71358315]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;properties&quot;: {&quot;lower_left&quot;: [-122.50948916666667, 37.708448], &quot;upper_right&quot;: [-122.50424733333334, 37.71358315]}, &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_f5aacfc1a27efcbe75b1dc9d7142e2da_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;1, 1&quot;, &quot;fillColor&quot;: &quot;White&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 0.7};
#             }
#         }
#
#         function geo_json_f5aacfc1a27efcbe75b1dc9d7142e2da_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f5aacfc1a27efcbe75b1dc9d7142e2da = L.geoJson(null, {
#                 onEachFeature: geo_json_f5aacfc1a27efcbe75b1dc9d7142e2da_onEachFeature,
#
#                 style: geo_json_f5aacfc1a27efcbe75b1dc9d7142e2da_styler,
#         });
#
#         function geo_json_f5aacfc1a27efcbe75b1dc9d7142e2da_

# %%
# manipulate numpy array to display on the grid
result = np.random.randint(0, 5, (20,30))
result_flip = np.flip(result, axis=0)
result_flip_flat = result_flip.flatten()

# %%
# create grid with colors 
m = folium.Map([sf_lat, sf_long], zoom_start = 12, tiles='cartodbpositron')

grid = get_geojson_grid(upper_right, lower_left, nlat=20, nlong=30)

# Add GeoJson to map
for i, box in enumerate(grid):
    geo_json = json.dumps(box)

    color = plt.cm.Reds(result_flip_flat[i] / 5)
    color = mpl.colors.to_hex(color)

    gj = folium.GeoJson(geo_json,
                        style_function=lambda feature, color=color: {
                                                                        'fillColor': color,
                                                                        'color':"black",
                                                                        'weight': 2,
                                                                        'dashArray': '5, 5',
                                                                        'fillOpacity': 0.55,
                                                                    })
    m.add_child(gj)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_499562de7f29ce7d684a84815a92d980 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_499562de7f29ce7d684a84815a92d980&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_499562de7f29ce7d684a84815a92d980 = L.map(
#                 &quot;map_499562de7f29ce7d684a84815a92d980&quot;,
#                 {
#                     center: [37.7597995, -122.4361035],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3ceec12c5725ed4a910323b2ee70a44 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_499562de7f29ce7d684a84815a92d980);
#
#
#         function geo_json_1757c627fce0d046dfa44cc1cea68ac0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#fff5f0&quot;, &quot;fillOpacity&quot;: 0.55, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_1757c627fce0d046dfa44cc1cea68ac0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1757c627fce0d046dfa44cc1cea68ac0 = L.geoJson(null, {
#                 onEachFeature: geo_json_1757c627fce0d046dfa44cc1cea68ac0_onEachFeature,
#
#                 style: geo_json_1757c627fce0d046dfa44cc1cea68ac0_styler,
#         });
#
#         function geo_json_1757c627fce0d046dfa44cc1cea68ac0_add (data) {
#             geo_json_1757c627fce0d046dfa44cc1cea68ac0
#                 .addData(data)
#                 .addTo(map_499562de7f29ce7d684a84815a92d980);
#         }
#             geo_json_1757c627fce0d046dfa44cc1cea68ac0_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.514731, 37.71358315], [-122.50948916666667, 37.71358315], [-122.50948916666667, 37.708448], [-122.514731, 37.708448], [-122.514731, 37.71358315]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;properties&quot;: {&quot;lower_left&quot;: [-122.514731, 37.708448], &quot;upper_right&quot;: [-122.50948916666667, 37.71358315]}, &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_af2b62681d8f2bc0c7a74eff73c8d7a0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#fff5f0&quot;, &quot;fillOpacity&quot;: 0.55, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_af2b62681d8f2bc0c7a74eff73c8d7a0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_af2b62681d8f2bc0c7a74eff73c8d7a0 = L.geoJson(null, {
#                 onEachFeature: geo_json_af2b62681d8f2bc0c7a74eff73c8d7a0_onEachFeature,
#
#                 style: geo_json_af2b62681d8f2bc0c7a74eff73c8d7a0_styler,
#         });
#
#         function geo_json_af2b62681d8f2bc0c7a74eff73c8d7a0_add (data) {
#             geo_json_af2b62681d8f2bc0c7a74eff73c8d7a0
#                 .addData(data)
#                 .addTo(map_499562de7f29ce7d684a84815a92d980);
#         }
#             geo_json_af2b62681d8f2bc0c7a74eff73c8d7a0_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.50948916666667, 37.71358315], [-122.50424733333334, 37.71358315], [-122.50424733333334, 37.708448], [-122.50948916666667, 37.708448], [-122.50948916666667, 37.71358315]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;properties&quot;: {&quot;lower_left&quot;: [-122.50948916666667, 37.708448], &quot;upper_right&quot;: [-122.50424733333334, 37.71358315]}, &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_acc90340db56afef60a1bfd832cfb785_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#fff5f0&quot;, &quot;fillOpacity&quot;: 0.55, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_acc90340db56afef60a1bfd832cfb785_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_acc90340db56afef60a1bfd832cfb785 = L.geoJson(null, {
#                 onEachFeature: geo_json_acc90340db56afef60a1bfd832cfb785_onEachFeature,
#
#                 style: geo_json_acc90340db56afef60a1bfd832cfb785_styler,
#         });
#
#         function geo_json_acc90340db56afef60a1bfd832cfb785
